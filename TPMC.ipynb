# %%
import numpy as np
import matplotlib.pylab as plt

# %%
# out put planets parameters, t,i1,a1,e1,inc1,M1,w1,O1
#                             t,i1,x1,y1,z1,vx1,vy1,vz1

# %%
ls
# Out:
# 10000periodos/  asd/            graf.R     newPC/        planet2.dat
# 1.txt           backup/         largota/   notas         planet3.dat
# 5periodos/      conrelativity/  ncorp9.f   orbitas.jpeg  planets.dat
# a.out           finales/        ncorp9.in  planet1.dat   pruebas/

# %%
cd newPC/coord5P/
# Out:
# /home/agustin/facultad/mecanicaceleste/tpNcorp/newPC/coord5P

# %%
p1 = np.loadtxt('planet1.dat')
p2 = np.loadtxt('planet2.dat')
p3 = np.loadtxt('planet3.dat')

# %%
#cambiando los parametros se chequea que nada se descajeta.
plt.plot(p1[:,0],p1[:,2])
plt.plot(p2[:,0],p2[:,2])
plt.plot(p3[:,0],p3[:,2])

# %%
cd ..
# Out:
# /home/agustin/facultad/mecanicaceleste/tpNcorp

# %%
#para mantener la estabilidad del sistema tengo que eliminar el primer planeta.
p1 = np.loadtxt('planet1.dat')
p2 = np.loadtxt('planet2.dat')
#p3 = np.loadtxt('planet3.dat')
len(p1)
# Out:
# 5001

# %%
plt.plot(p2[:,0],p1[:,2])
